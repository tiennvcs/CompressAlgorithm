# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# %cd /gdrive/My Drive/School_UIT/Semester IV/[CS232] Introduction to Multimedia Computing/Working/Final Project/Data_Compression
# Out:
# /gdrive/My Drive/School_UIT/Semester IV/[CS232] Introduction to Multimedia Computing/Working/Final Project/Data_Compression

# %%
! python main.py -al kmean --clusters 32 -i experiments/image/1080x1080/image1.jpg

# %%
! python main.py -al kmean --clusters 64 -i experiments/image/1080x1080/image1.jpg
# Out:
# [INFO] Preprocressing ...
# [INFO] Compressing ...
# [INFO] Calculate the needed bits...
# - The number of bits needed represent image is 27993600
# - The number of bits needed represent the ENCODED image: 20995200
# [INFO] The compression ratio is 1.3333333333333333
# [INFO] Decompressing ...
